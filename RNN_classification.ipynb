# %% [markdown]
# <a href="https://colab.research.google.com/github/ugurcancakal/network_pytorch/blob/master/RNN_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # RNN in PyTorch II

# %%
# @title Imports

import torch
import torch.nn as nn
from torch.autograd import Variable

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
# %matplotlib inline

# %%
#@title Video: RNN II

from IPython.display import YouTubeVideo
video = YouTubeVideo(id="1vGOQAel2yU?t", width=854, height=480, fs=1)
print("Video available at https://youtube.com/watch?v=" + video.id)
video
# Out:
# Video available at https://youtube.com/watch?v=1vGOQAel2yU?t
#         <iframe
#             width="854"
#             height="480"
#             src="https://www.youtube.com/embed/1vGOQAel2yU?t?fs=1"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# @title Download Pictures and slides
import os, requests
fname = ['rnn_basic.png']
fname.append('rnn_typical.png')
fname.append('rnn_names.png')
fname.append('rnn_char_embedding.png')
fname.append('rnn_input_representation.png')
fname.append('Lecture 13_ RNN II.pptx')

id = ["1pQeafV2u5-d-bKBE33SLFGFsTvdUkOsk"]
# id.append("1-SSa_jAQcguYfmYFlqN8uQTPIDdgRGQU")
# id.append("1mhJKJvpjafLg97M-xNcijpI7LIykNr3B")
# id.append("1hbatywSvdF-Scnne--rrGfvQezoHV5Ia")
# id.append("1St_H-7rikjYlUkP1fKRREV4SAOvYApy-")
id.append("1M7qXz_lQhhn6Dmib8z_Ya3pGpsxyhtV3")

for j in range(len(id)):
  if not os.path.isfile(fname[j]):
    try:
      temp = id[j]
      # !gdown --id $temp
    except requests.ConnectionError:
      print("!!! Failed to download data !!!")
  else:
    print("{} is already in the current directory".format(fname[j]))
# Out:
# rnn_basic.png is already in the current directory
# Lecture 13_ RNN II.pptx is already in the current directory

# %% [markdown]
# # RNN Classification

# %%
from IPython.display import Image
Image('rnn_typical.png')

# %%
from IPython.display import Image
Image('rnn_names.png')

# %%
from IPython.display import Image
Image('rnn_char_embedding.png')

# %%
from IPython.display import Image
Image('rnn_input_representation.png')

# %%
def str2ascii_arr(name):
  arr = [ord(c) for c in name]
  return arr, len(arr)

# %%
# @title MAIN
rnn_input_size = 128 # how many different characters
hidden_size = 100
if __name__ == '__main__':
  names = ['adylov', 'solan', 'hard', 'san']
  nn.Embedding(input_voc_size, hidden_size)
  for name in names:
    arr, _ = str2ascii_arr(name)
    print(name, arr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-33e79ed35593> in <module>()
#       4 if __name__ == '__main__':
#       5   names = ['adylov', 'solan', 'hard', 'san']
# ----> 6   nn.Embedding(input_voc_size, hidden_size)
#       7   for name in names:
#       8     arr, _ = str2ascii_arr(name)
#
# NameError: name 'input_voc_size' is not defined
